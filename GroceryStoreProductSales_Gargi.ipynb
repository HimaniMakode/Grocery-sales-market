# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import re
import random
from scipy.stats import linregress

# %%
# Take in all of our Grocery Store data and read it into pandas
Categories = "Resources_final/Categories_Modified.csv"
Cities = "Resources_final/cities_Modify.csv"
Countries = "Resources_final/countries_Modified.csv"
Customers = "Resources_final/customers_modified.csv"
Employees = "Resources_final/employees_Modified.csv"
Products = "Resources_final/products_Modified.csv"
Sales = "Resources_final/sales_Modified.csv"

products_df = pd.read_csv(Products)
sales_df = pd.read_csv(Sales)
countries_df = pd.read_csv(Countries)
categories_df = pd.read_csv(Categories)
cities_df = pd.read_csv(Cities)

# %%
products_df
# Out:
#      ProductID                        ProductName    Price  CategoryID  \
# 0            1                Flour - Whole Wheat  742,988           3
# 1            2         Cookie Chocolate Chip With  912,329           3
# 2            3                 Onions - Cippolini   91,379           9
# 3            4         Sauce - Gravy, Au Jus, Mix  543,055           9
# 4            5             Artichokes - Jerusalem  654,771           2
# 5            6         Wine - Magnotta - Cab Sauv  797,184           8
# 6            7         Table Cloth - 53x69 Colour   31,837           9
# 7            8                   Halibut - Steaks  898,573           5
# 8            9                     Rabbit - Whole  844,219          11
# 9           10                        Scampi Tail  950,957           4
# 10          11               Garbage Bags - Clear   62,949           9
# 11          12               Ezy Change Mophandle  493,356           4
# 12          13                         Water, Tap  282,232          11
# 13          14                 Beef - Top Sirloin   33,324           7
# 14          15              Spoon - Soup, Plastic   32,442           1
# 15          16           Kellogs Special K Cereal  547,246           2
# 16          17           Wine - White, Mosel Gold  439,182          10
# 17          18                Lamb - Whole, Fresh  233,966          10
# 18          19                    Tea - Earl Grey  225,614           3
# 19          20               Chocolate - Feathers  859,011           3
# 20          21                               Kiwi  467,252           7
# 21          22              Rice - Jasmine Sented  278,955           6
# 22          23            Crab - Imitation Flakes  790,184          11
# 23          24  Beer - Alexander Kieths, Pale Ale   89,037           3
# 24          25            Soupcontfoam16oz 116con  807,666          10
# 25          26                Squid U5 - Thailand  337,821          11
# 26          27       Chocolate - Compound Coating  171,724           1
# 27          28             Sobe - Tropical Energy  123,153           9
# 28          29                     Spinach - Baby  335,883           7
# 29          30        Cheese - Brie, Triple Creme   67,899           6
# ..         ...                                ...      ...         ...
# 422        423       Fish - Scallops, Cold Smoked  558,531           2
# 423        424                 Vinegar - Tarragon  858,828           3
# 424        425            Wine - Redchard Merritt  567,898           4
# 425        426           Scallops - Live In Shell  835,759           3
# 426        427  Wine - Vineland Estate Semi - Dry  463,252           3
# 427        428             Wine - Ruffino Chianti   47,235           7
# 428        429                  Beef - Short Loin  576,013           4
# 429        430                          Milk - 1%  462,589           2
# 430        431   Muffin Chocolate Individual Wrap  199,957          10
# 431        432      Beer - Original Organic Lager  327,153           2
# 432        433            Beans - Kidney, Red Dry  398,762           3
# 433        434             Cookie - Dough Variety  711,551           7
# 434        435                   Salsify, Organic  326,109           8
# 435        436            Table Cloth 81x81 White  679,063           7
# 436        437     Chips Potato All Dressed - 43g  835,856          10
# 437        438                     Juice - Orange  449,415           2
# 438        439             Beef - Chuck, Boneless  560,919          11
# 439        440                      Pork - Inside  329,092           1
# 440        441                       Blackberries  729,439           3
# 441        442      Wine - Ej Gallo Sierra Valley  729,041           6
# 442        443               Lettuce - Spring Mix  900,169           2
# 443        444                 Cheese - Cambozola  440,886           8
# 444        445            Pastry - Choclate Baked  592,467           8
# 445        446                 Sunflower Seed Raw  490,452           7
# 446        447         Salmon - Atlantic, Skin On   34,198           3
# 447        448           Gatorade - Xfactor Berry  768,988           5
# 448        449              Nantuket Peach Orange  421,414           4
# 449        450      Wine - Vidal Icewine Magnotta    7,107           3
# 450        451    Soup - Campbells Tomato Ravioli  935,384           1
# 451        452            Napkin White - Starched  285,653          11
#
#       Class ModifyDate Resistant IsAllergic  VitalityDays
# 0    Medium    21:49.2   Durable        NaN           NaN
# 1    Medium    39:11.0       NaN        NaN           NaN
# 2    Medium    11:51.6      Weak      False         111.0
# 3    Medium    46:28.9   Durable        NaN           NaN
# 4       Low    13:35.4   Durable       True          27.0
# 5      High    08:39.7       NaN        NaN           NaN
# 6    Medium    14:30.0   Durable      False           NaN
# 7    Medium    21:21.9       NaN       True         108.0
# 8    Medium    12:04.7   Durable        NaN           NaN
# 9       Low    11:46.0      Weak       True         105.0
# 10      Low    02:21.3   Durable       True          67.0
# 11   Medium    49:59.0   Durable       True           NaN
# 12      Low    49:10.9   Durable      False          69.0
# 13   Medium    40:47.8   Durable       True           NaN
# 14      Low    47:09.3      Weak       True           NaN
# 15      Low    25:47.1   Durable       True           NaN
# 16   Medium    03:04.9       NaN        NaN           NaN
# 17   Medium    45:04.7       NaN      False           NaN
# 18   Medium    39:53.3      Weak       True          94.0
# 19      Low    13:57.5   Durable       True           NaN
# 20     High    59:46.1   Durable        NaN           NaN
# 21   Medium    08:23.6      Weak        NaN          48.0
# 22   Medium    18:29.9   Durable       True           NaN
# 23   Medium    36:02.4   Durable       True          65.0
# 24     High    30:41.2   Durable       True           NaN
# 25   Medium    31:27.0      Weak      False          10.0
# 26   Medium    27:27.3       NaN        NaN          86.0
# 27     High    23:48.2   Durable       True           NaN
# 28      Low    21:24.0   Durable       True          50.0
# 29      Low    28:46.7      Weak        NaN          72.0
# ..      ...        ...       ...        ...           ...
# 422  Medium    59:12.3       NaN        NaN          35.0
# 423  Medium    37:11.0       NaN      False           NaN
# 424  Medium    15:31.2      Weak        NaN           NaN
# 425     Low    44:18.0       NaN        NaN           NaN
# 426    High    23:58.3   Durable      False           NaN
# 427  Medium    33:10.9       NaN       True          48.0
# 428    High    41:22.2      Weak      False           NaN
# 429     Low    20:35.3   Durable      False          84.0
# 430  Medium    36:42.1      Weak      False          89.0
# 431    High    43:50.0       NaN      False          44.0
# 432     Low    47:07.0   Durable      False          11.0
# 433     Low    07:25.5      Weak       True           NaN
# 434    High    15:25.0   Durable       True           NaN
# 435    High    46:43.4       NaN      False          25.0
# 436    High    11:12.2   Durable        NaN           NaN
# 437     Low    13:52.4   Durable        NaN           NaN
# 438  Medium    18:51.0       NaN      False         108.0
# 439     Low    02:16.2       NaN        NaN           NaN
# 440  Medium    42:50.3      Weak        NaN           NaN
# 441  Medium    42:25.6       NaN        NaN         106.0
# 442     Low    10:08.0       NaN      False          79.0
# 443     Low    58:04.5   Durable        NaN          56.0
# 444    High    06:20.6      Weak        NaN          76.0
# 445    High    06:41.1       NaN        NaN          18.0
# 446    High    11:34.2       NaN       True           NaN
# 447     Low    33:00.5       NaN      False           NaN
# 448     Low    11:45.4       NaN      False           NaN
# 449     Low    00:00.6       NaN        NaN           NaN
# 450     Low    51:38.8   Durable      False           NaN
# 451     Low    39:42.9   Durable        NaN           NaN
#
# [452 rows x 9 columns]

# %%
sales_df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       NaN
# 1        2             16       25011         61         7       NaN
# 2        3             13       94024         23        24       NaN
# 3        4              8       73966        176        19       0.2
# 4        5             10       32653        310         9       NaN
#
#    TotalPrice SalesDate     TransactionNumber
# 0           0   38:25.4  FQL4S94E4ME1EZFTG42G
# 1           0   03:31.1  12UGLX40DJ1A5DTFBHB8
# 2           0   31:56.9  5DT8RCPL87KI5EORO7B0
# 3           0   43:55.4  R3DR9MLD5NR76VO17ULE
# 4           0   37:03.9  4BGS0Z5OMAZ8NDAFHHP3

# %%
#4.Build a scatter plot identifying total sales revenue per product nationwide[Gargi]

# Merge the first two datasets on ProductID so that no data is lost 
combined_productSales_df = pd.merge(sales_df, products_df,
                                 how='outer', on='ProductID')
# combined_productSales_df["Price"] = pd.to_numeric(combined_productSales_df['Price'],errors='coerce')
combined_productSales_df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       NaN
# 1      651              2       36984        381        10       0.1
# 2      984             18       98474        381        25       0.2
# 3     1077             14       47778        381        13       0.2
# 4     1396              4       62919        381        16       NaN
#
#    TotalPrice SalesDate     TransactionNumber       ProductName    Price  \
# 0           0   38:25.4  FQL4S94E4ME1EZFTG42G  Vaccum Bag 10x13  442,337
# 1           0   10:35.2  XQL4NP8GP3LIJBPC78BR  Vaccum Bag 10x13  442,337
# 2           0   51:09.2  W57VJBEIM4PJ99L40VCT  Vaccum Bag 10x13  442,337
# 3           0   51:47.2  JRWW0M7TOFQA29YTPL9Y  Vaccum Bag 10x13  442,337
# 4           0       NaN  DFDKR0C1CPMTNMTHWN9Z  Vaccum Bag 10x13  442,337
#
#    CategoryID Class ModifyDate Resistant IsAllergic  VitalityDays
# 0           1  High    26:53.6       NaN        NaN          41.0
# 1           1  High    26:53.6       NaN        NaN          41.0
# 2           1  High    26:53.6       NaN        NaN          41.0
# 3           1  High    26:53.6       NaN        NaN          41.0
# 4           1  High    26:53.6       NaN        NaN          41.0

# %%
#combined_productSales_df.head()['Price'][0]
reg = re.compile(',')
#reg.sub('', combined_productSales_df.head()['Price'][0])
combined_productSales_df['Price'] = combined_productSales_df['Price'].apply(lambda s: reg.sub('', s))
combined_productSales_df['Price'] = combined_productSales_df['Price'].astype(float)

# %%
#Total Sales Per SalesID
combined_productSales_df["Total Sales"] = combined_productSales_df["Quantity"] * combined_productSales_df["Price"]
combined_productSales_df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       NaN
# 1      651              2       36984        381        10       0.1
# 2      984             18       98474        381        25       0.2
# 3     1077             14       47778        381        13       0.2
# 4     1396              4       62919        381        16       NaN
#
#    TotalPrice SalesDate     TransactionNumber       ProductName     Price  \
# 0           0   38:25.4  FQL4S94E4ME1EZFTG42G  Vaccum Bag 10x13  442337.0
# 1           0   10:35.2  XQL4NP8GP3LIJBPC78BR  Vaccum Bag 10x13  442337.0
# 2           0   51:09.2  W57VJBEIM4PJ99L40VCT  Vaccum Bag 10x13  442337.0
# 3           0   51:47.2  JRWW0M7TOFQA29YTPL9Y  Vaccum Bag 10x13  442337.0
# 4           0       NaN  DFDKR0C1CPMTNMTHWN9Z  Vaccum Bag 10x13  442337.0
#
#    CategoryID Class ModifyDate Resistant IsAllergic  VitalityDays  Total Sales
# 0           1  High    26:53.6       NaN        NaN          41.0    3096359.0
# 1           1  High    26:53.6       NaN        NaN          41.0    4423370.0
# 2           1  High    26:53.6       NaN        NaN          41.0   11058425.0
# 3           1  High    26:53.6       NaN        NaN          41.0    5750381.0
# 4           1  High    26:53.6       NaN        NaN          41.0    7077392.0

# %%
#Combine the Total Revenue Per Product
item = combined_productSales_df.groupby(["ProductID", "ProductName", "Price"])

product_unique = item["ProductName"].nunique()
product_unique
sum_quantity = item["Quantity"].sum()
sum_quantity
sum_TotalSales = item["Total Sales"].sum()
sum_TotalSales
price = item["Price"].max()
df = pd.DataFrame({"Quantity": sum_quantity, "Sum Of Total Sales Per Product": sum_TotalSales})
newdfNum = df.reset_index()
newdf = df.reset_index()
newdfNum.head()
# Out:
#    ProductID                 ProductName     Price  Quantity  \
# 0          1         Flour - Whole Wheat  742988.0     28687
# 1          2  Cookie Chocolate Chip With  912329.0     29248
# 2          3          Onions - Cippolini   91379.0     30386
# 3          4  Sauce - Gravy, Au Jus, Mix  543055.0     30015
# 4          5      Artichokes - Jerusalem  654771.0     29769
#
#    Sum Of Total Sales Per Product
# 0                    2.131410e+10
# 1                    2.668380e+10
# 2                    2.776642e+09
# 3                    1.629980e+10
# 4                    1.949188e+10

# %%
#Adding currency to the table above.
sorted_item_price = newdf.sort_values(["Sum Of Total Sales Per Product"], ascending = False)
newdf['Sum Of Total Sales Per Product'] = newdf['Sum Of Total Sales Per Product'].apply(lambda x: f'${x/100:,.2f}')
newdf['Price'] = newdf['Price'].apply(lambda x: f'${x/100:,.2f}')
newdf.head()
# Out:
#    ProductID                 ProductName      Price  Quantity  \
# 0          1         Flour - Whole Wheat  $7,429.88     28687
# 1          2  Cookie Chocolate Chip With  $9,123.29     29248
# 2          3          Onions - Cippolini    $913.79     30386
# 3          4  Sauce - Gravy, Au Jus, Mix  $5,430.55     30015
# 4          5      Artichokes - Jerusalem  $6,547.71     29769
#
#   Sum Of Total Sales Per Product
# 0                $213,140,967.56
# 1                $266,837,985.92
# 2                 $27,766,422.94
# 3                $162,997,958.25
# 4                $194,918,778.99

# %%
#Price Vs Quantity Sold Scatter Plot Distribution.
plt.figure(figsize=(15, 8))
plt.scatter(x=newdfNum['Quantity'], y=newdfNum['Price'], marker="o", facecolors="coral", edgecolors="black", alpha=0.75)
plt.title('Scatter Plot Showing Price Vs Quantity')
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.grid()
plt.savefig("output/Sales_Vs_TotalSales_ScatterPlot.png")

# %%
x = newdfNum['ProductName'][:40]
x_axis = np.arange(len(x))
y = newdfNum['Sum Of Total Sales Per Product'][:40]
y_axis = np.arange(len(y))

plt.figure(figsize=(15, 7))
plt.bar(x, y)
plt.xticks(x, rotation=80, ha='right')
plt.title('Total Sales Per Product Evaluation of the Grocery Market')
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.show()
plt.savefig("output/Sales_Vs_TotalSales_BarGraph.png")

# %%
#7.Which are perishable to durable products in grocery store.(scatter plot)[Gargi]
products_df
sorted_product_resistance = products_df.sort_values(["Resistant"], ascending = False)
sorted_product_resistance.head()
# Out:
#      ProductID                   ProductName    Price  CategoryID   Class  \
# 211        212          Curry Paste - Madras   61,746           2    High
# 304        305  Pastry - Cheese Baked Scones  910,997           8  Medium
# 360        361        Coffee Decaf Colombian  364,516           2  Medium
# 135        136                  Vol Au Vents  243,913          10  Medium
# 239        240    Wine - Chablis 2003 Champs  708,596           4     Low
#
#     ModifyDate Resistant IsAllergic  VitalityDays
# 211    52:59.6      Weak       True          97.0
# 304    16:12.9      Weak       True          19.0
# 360    54:23.0      Weak       True          71.0
# 135    33:43.5      Weak       True           NaN
# 239    57:29.6      Weak      False           NaN

# %%
countries_df.head()
# Out:
#    Projects Stabilizing CountryName CountryCode
# 0                     1     Armenia          AN
# 1                     2      Canada          FO
# 2                     3      Belize          MK
# 3                     4      Uganda          LV
# 4                     5    Thailand          VI

# %%
categories_df.head()
# Out:
#    CategoryID CategoryName
# 0           1  Confections
# 1           2   Shell fish
# 2           3      Cereals
# 3           4        Dairy
# 4           5    Beverages

# %%
cities_df.head()
# Out:
#    CityID        CityName  Zipcode  CountryID
# 0       1          Dayton    80563         32
# 1       2         Buffalo    17420         32
# 2       3         Chicago    44751         32
# 3       4         Fremont    20641         32
# 4       5  Virginia Beach    62389         32

# %%
# combined_productSales_df["Price"] = pd.to_numeric(combined_productSales_df['Price'],errors='coerce')
combined_productSales_df.head()
# Out:
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       NaN
# 1      651              2       36984        381        10       0.1
# 2      984             18       98474        381        25       0.2
# 3     1077             14       47778        381        13       0.2
# 4     1396              4       62919        381        16       NaN
#
#    TotalPrice SalesDate     TransactionNumber       ProductName     Price  \
# 0           0   38:25.4  FQL4S94E4ME1EZFTG42G  Vaccum Bag 10x13  442337.0
# 1           0   10:35.2  XQL4NP8GP3LIJBPC78BR  Vaccum Bag 10x13  442337.0
# 2           0   51:09.2  W57VJBEIM4PJ99L40VCT  Vaccum Bag 10x13  442337.0
# 3           0   51:47.2  JRWW0M7TOFQA29YTPL9Y  Vaccum Bag 10x13  442337.0
# 4           0       NaN  DFDKR0C1CPMTNMTHWN9Z  Vaccum Bag 10x13  442337.0
#
#    CategoryID Class ModifyDate Resistant IsAllergic  VitalityDays  Total Sales
# 0           1  High    26:53.6       NaN        NaN          41.0    3096359.0
# 1           1  High    26:53.6       NaN        NaN          41.0    4423370.0
# 2           1  High    26:53.6       NaN        NaN          41.0   11058425.0
# 3           1  High    26:53.6       NaN        NaN          41.0    5750381.0
# 4           1  High    26:53.6       NaN        NaN          41.0    7077392.0
