# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame

path = "Resources_final/"

countries = pd.read_csv(path + "countries_Modified.csv", sep=",")
cities = pd.read_csv(path + "cities_Modify.csv", sep=",")
employees = pd.read_csv(path + "employees_Modified.csv", sep=",")
products = pd.read_csv(path + "products_Modified.csv", sep=",")
categories = pd.read_csv(path + "Categories_Modified.csv", sep=",")
customers = pd.read_csv(path + "customers_modified.csv", sep=",")
sales = pd.read_csv(path + "sales_Modified.csv", sep=",")

# %% [markdown]
# # Check-point
#
# The below code allows us to check the quantity of each products.

# %%
grouped = sales.groupby("ProductID")


Total_count = grouped["Quantity"].sum()

Product_quantity = pd.DataFrame({"Quantity Count": Total_count })
Product_quantity.head()
# Out:
#            Quantity Count
# ProductID
# 1                   28687
# 2                   29248
# 3                   30386
# 4                   30015
# 5                   29769

# %% [markdown]
# # Merge of sales and product data

# %%
#Merging sales and product data
sales_product_merge = pd.merge(pd.merge(sales, products, how="outer", on="ProductID"),
                               categories, how="outer", on="CategoryID")
                              
sales_product_merge
# Out:
#          SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0              1              6       27039        381         7       NaN
# 1            651              2       36984        381        10       0.1
# 2            984             18       98474        381        25       0.2
# 3           1077             14       47778        381        13       0.2
# 4           1396              4       62919        381        16       NaN
# 5           1998              9       36164        381        10       0.2
# 6           2750             22       48026        381        13       NaN
# 7           4283             17       35899        381        10       0.2
# 8           4303              9       15370        381         4       0.2
# 9           4649              4       41256        381        11       0.2
# 10          5397              6       67069        381        17       NaN
# 11          5732             11       41228        381        11       NaN
# 12          5814              3         463        381         1       NaN
# 13          6021             18       97868        381        25       NaN
# 14          6039             19       41253        381        11       NaN
# 15          6200             17       96683        381        25       NaN
# 16          6492             19       22227        381         6       NaN
# 17          6604              7       68605        381        18       NaN
# 18          7004             11        1059        381         1       NaN
# 19          7059             15       71062        381        18       NaN
# 20          7176             16       73190        381        19       0.2
# 21          8282             17       96116        381        25       0.1
# 22          8292              8       51387        381        14       NaN
# 23          8835             17       35563        381        10       NaN
# 24          9524              3       39875        381        11       NaN
# 25          9541             16       53819        381        14       NaN
# 26          9833             11       21521        381         6       0.1
# 27         10191              6       27043        381         7       NaN
# 28         10365             10       18260        381         5       NaN
# 29         10607              5       83544        381        22       NaN
# ...          ...            ...         ...        ...       ...       ...
# 1048545  1036100              5       24549        386         7       NaN
# 1048546  1036178              6        9333        386         3       NaN
# 1048547  1036721             23       52869        386        14       NaN
# 1048548  1037353             15       31470        386         8       NaN
# 1048549  1038199             15       72250        386        19       NaN
# 1048550  1038575             14       49225        386        13       NaN
# 1048551  1039489             23       31789        386         9       NaN
# 1048552  1039491              8       34193        386         9       NaN
# 1048553  1040378             21       47091        386        12       0.2
# 1048554  1040725             14        9183        386         3       NaN
# 1048555  1040868             19       82290        386        21       NaN
# 1048556  1040876             22       70375        386        18       NaN
# 1048557  1041056              1       73644        386        19       NaN
# 1048558  1041299              9       16259        386         5       NaN
# 1048559  1042051             19       81001        386        21       0.1
# 1048560  1042479             22       89388        386        23       NaN
# 1048561  1042495             23       32166        386         9       NaN
# 1048562  1042647              9       96190        386        25       NaN
# 1048563  1042963              4       21686        386         6       NaN
# 1048564  1043271              2       57685        386        15       NaN
# 1048565  1044160             12       24607        386         7       0.1
# 1048566  1044739             12       24599        386         7       NaN
# 1048567  1045007             22       29079        386         8       NaN
# 1048568  1045928             12       62689        386        16       NaN
# 1048569  1046222             10       57516        386        15       NaN
# 1048570  1047081             22       88910        386        23       NaN
# 1048571  1047106             11         446        386         1       NaN
# 1048572  1047762             15       50774        386        13       NaN
# 1048573  1047987             22       30286        386         8       NaN
# 1048574  1048075             23       32168        386         9       NaN
#
#          TotalPrice SalesDate     TransactionNumber  \
# 0                 0   38:25.4  FQL4S94E4ME1EZFTG42G
# 1                 0   10:35.2  XQL4NP8GP3LIJBPC78BR
# 2                 0   51:09.2  W57VJBEIM4PJ99L40VCT
# 3                 0   51:47.2  JRWW0M7TOFQA29YTPL9Y
# 4                 0       NaN  DFDKR0C1CPMTNMTHWN9Z
# 5                 0   50:51.3  ZDOFF40MSTU235347SRQ
# 6                 0   21:24.4  5Z7T6BWY0C6AFOCTXQQ0
# 7                 0   09:42.6  NPI980H3UQQ229ELYO6E
# 8                 0   31:04.3  FXLOOSXLUB9PKW78R2SU
# 9                 0   37:05.4  A8A6LCUKKBZ214KGC2JZ
# 10                0   02:54.4  PMZ97U3GRLJEPA8WN8QN
# 11                0   03:35.7  YYIFOATZBL7MQZJC6J1F
# 12                0   50:59.9  A2AQB6OBME33D64QZV41
# 13                0   41:12.4  MZ3URWY9NVBI457V0QRA
# 14                0   58:45.4  016EJYYGK00VLFTZ13PO
# 15                0   04:50.6  93ICY3YVWMLFHXDJG7QZ
# 16                0   07:08.8  4KYUSPX57G1HKRYT8863
# 17                0   26:08.5  SVFYBKOHLHO35DM6FCVF
# 18                0   36:25.5  NXDB3GPC0HGC0FA4YJJ7
# 19                0   25:47.2  RSELK6TQ09E0D4WZBRAS
# 20                0   33:37.2  VQE0L1H9Z5TWQ5Q4IJR2
# 21                0   17:17.7  ID9AO6JXT8MBMK57M117
# 22                0   31:24.3  NR0DK1X5U1W8C9T64QDO
# 23                0   00:45.6  YP1V91NUIILD4TY709IN
# 24                0   48:06.4  ZCYH431ZU5P4OXQC07XD
# 25                0   26:19.4  3HFCXAOUW9JNJ1LLGNG5
# 26                0   20:10.1  EYQ2DOPWCZOJJT7IU4VY
# 27                0   26:17.3  E3AKJ9KEPUXSVL72ULCP
# 28                0   30:49.6  SZR4FXOJ7C66F9JPK5OB
# 29                0   07:09.6  XIL98S8VY3VIAZYIXO2A
# ...             ...       ...                   ...
# 1048545           0   56:20.2  1O25KGETB5H26XCOIMZR
# 1048546           0   46:23.0  GXDQLOQNFL5HUVV19PDT
# 1048547           0   12:32.6  FL0P9SF8TTZXCBIHHWDJ
# 1048548           0   01:37.4  IYM7WYYR8QJ9RJNAW5JO
# 1048549           0   09:56.6  FG8ZYUFLUB3LW8YBU5ZD
# 1048550           0   40:18.0  N114HVX8NH8LHUW0VP4T
# 1048551           0   52:12.9  OM948UHKKO3SC7QGVHI8
# 1048552           0   28:02.9  3KYJLEMPQEBOQJFCAO3Z
# 1048553           0   39:32.1  KIU4ZGXRWRAV7HFG0KDV
# 1048554           0   00:21.9  TEL4NSCOEH4LF8587GGS
# 1048555           0   50:10.9  19VC6AK5FVXBIM5205DR
# 1048556           0   28:13.7  WUGPQET5WK5ZQ9H67TTS
# 1048557           0   15:46.5  J81VMGAXFTCQ0ASGQ7Y7
# 1048558           0   35:48.8  5RNL8BANFARI9PPT5E75
# 1048559           0   20:08.8  Q0C13IJ4OZDCBJ4RLIBE
# 1048560           0   44:20.3  1ARECRO155HRWOYM6YWV
# 1048561           0   24:50.8  RCEXNDZAB27L23LZ6SH0
# 1048562           0   46:53.7  ZZ48HVVCOQ5F5JT68HD3
# 1048563           0   51:09.6  CJWSLKJG99EV9Z5CEB2V
# 1048564           0   20:25.0  SPPGOW8V406MZ1GYLLMS
# 1048565           0   40:50.9  BWS0JG6CWGV1H7NPZW16
# 1048566           0   01:27.9  L0K5JEXS7EFY5LQ5QM61
# 1048567           0   18:05.0  WAA5840LFQ6G7T8KGXB8
# 1048568           0   05:36.6  TO0ZT87SXBJ15SNAMVHS
# 1048569           0   01:02.9  N84KK9C9000VJIXP8ZN5
# 1048570           0   11:29.9  FFURESOHDP2VL26JFDPV
# 1048571           0   51:04.8  5XPCP361OQPLP92B6GMD
# 1048572           0   02:00.1  59SKH8FKHY569TL3NM4D
# 1048573           0   02:04.2  55HXRQ7SIUC0OR24M8S4
# 1048574           0   05:03.0  SC93WTVDNK2BPQMGM36Q
#
#                          ProductName    Price  CategoryID   Class ModifyDate  \
# 0                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 1                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 2                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 3                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 4                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 5                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 6                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 7                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 8                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 9                   Vaccum Bag 10x13  442,337           1    High    26:53.6
# 10                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 11                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 12                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 13                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 14                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 15                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 16                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 17                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 18                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 19                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 20                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 21                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 22                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 23                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 24                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 25                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 26                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 27                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 28                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# 29                  Vaccum Bag 10x13  442,337           1    High    26:53.6
# ...                              ...      ...         ...     ...        ...
# 1048545  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048546  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048547  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048548  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048549  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048550  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048551  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048552  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048553  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048554  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048555  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048556  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048557  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048558  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048559  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048560  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048561  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048562  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048563  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048564  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048565  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048566  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048567  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048568  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048569  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048570  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048571  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048572  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048573  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
# 1048574  Sprouts - Baby Pea Tendrils  427,112          10  Medium    52:13.1
#
#         Resistant IsAllergic  VitalityDays CategoryName
# 0             NaN        NaN          41.0  Confections
# 1             NaN        NaN          41.0  Confections
# 2             NaN        NaN          41.0  Confections
# 3             NaN        NaN          41.0  Confections
# 4             NaN        NaN          41.0  Confections
# 5             NaN        NaN          41.0  Confections
# 6             NaN        NaN          41.0  Confections
# 7             NaN        NaN          41.0  Confections
# 8             NaN        NaN          41.0  Confections
# 9             NaN        NaN          41.0  Confections
# 10            NaN        NaN          41.0  Confections
# 11            NaN        NaN          41.0  Confections
# 12            NaN        NaN          41.0  Confections
# 13            NaN        NaN          41.0  Confections
# 14            NaN        NaN          41.0  Confections
# 15            NaN        NaN          41.0  Confections
# 16            NaN        NaN          41.0  Confections
# 17            NaN        NaN          41.0  Confections
# 18            NaN        NaN          41.0  Confections
# 19            NaN        NaN          41.0  Confections
# 20            NaN        NaN          41.0  Confections
# 21            NaN        NaN          41.0  Confections
# 22            NaN        NaN          41.0  Confections
# 23            NaN        NaN          41.0  Confections
# 24            NaN        NaN          41.0  Confections
# 25            NaN        NaN          41.0  Confections
# 26            NaN        NaN          41.0  Confections
# 27            NaN        NaN          41.0  Confections
# 28            NaN        NaN          41.0  Confections
# 29            NaN        NaN          41.0  Confections
# ...           ...        ...           ...          ...
# 1048545      Weak      False           NaN       Snails
# 1048546      Weak      False           NaN       Snails
# 1048547      Weak      False           NaN       Snails
# 1048548      Weak      False           NaN       Snails
# 1048549      Weak      False           NaN       Snails
# 1048550      Weak      False           NaN       Snails
# 1048551      Weak      False           NaN       Snails
# 1048552      Weak      False           NaN       Snails
# 1048553      Weak      False           NaN       Snails
# 1048554      Weak      False           NaN       Snails
# 1048555      Weak      False           NaN       Snails
# 1048556      Weak      False           NaN       Snails
# 1048557      Weak      False           NaN       Snails
# 1048558      Weak      False           NaN       Snails
# 1048559      Weak      False           NaN       Snails
# 1048560      Weak      False           NaN       Snails
# 1048561      Weak      False           NaN       Snails
# 1048562      Weak      False           NaN       Snails
# 1048563      Weak      False           NaN       Snails
# 1048564      Weak      False           NaN       Snails
# 1048565      Weak      False           NaN       Snails
# 1048566      Weak      False           NaN       Snails
# 1048567      Weak      False           NaN       Snails
# 1048568      Weak      False           NaN       Snails
# 1048569      Weak      False           NaN       Snails
# 1048570      Weak      False           NaN       Snails
# 1048571      Weak      False           NaN       Snails
# 1048572      Weak      False           NaN       Snails
# 1048573      Weak      False           NaN       Snails
# 1048574      Weak      False           NaN       Snails
#
# [1048575 rows x 18 columns]

# %% [markdown]
# # Insight-1: Allergic products among different categoriesID

# %%
#Allergic products 
allergic_products = sales_product_merge.groupby(["CategoryName","IsAllergic","ProductName"])

# Total sum of quantities
sum_of_quantity = allergic_products["Quantity"].sum()

#Convert into Dataframe
allergic_grouped_df = pd.DataFrame({"Max_Quantity_Sold": sum_of_quantity})
allergic_grouped_df.head()
# Out:
#                                                         Max_Quantity_Sold
# CategoryName IsAllergic ProductName
# Beverages    False      Assorted Desserts                           30140
#                         Bouq All Italian - Primerba                 30732
#                         Bread - Roll, Soft White Round              30488
#                         Cheese - Mozzarella                         30470
#                         Cheese - Taleggio D.o.p.                    31981

# %% [markdown]
# The above table seems that the CategoryName is not a reliable feature of this dataset, since for example we can see that the Cheese-Mozzarella product is classified as Beverages instead of Dairy.

# %%
# idxmax is used to filter the rows with max value in the column
allergic_max = allergic_grouped_df.loc[allergic_grouped_df.groupby(["CategoryName","IsAllergic"])["Max_Quantity_Sold"].idxmax()]

allergic_max_values = allergic_max.reset_index()
allergic_max_values
# Out:
#    CategoryName  IsAllergic                        ProductName  \
# 0     Beverages       False           Cheese - Taleggio D.o.p.
# 1     Beverages        True                     Mustard - Seed
# 2       Cereals       False         Sole - Dover, Whole, Fresh
# 3       Cereals        True                   Chocolate - Dark
# 4   Confections       False                Initation Crab Meat
# 5   Confections        True          Tea - Herbal Sweet Dreams
# 6         Dairy       False                     Apricots Fresh
# 7         Dairy        True           Wine - White Cab Sauv.on
# 8         Grain       False              Bandage - Fexible 1x3
# 9         Grain        True                        Milk Powder
# 10         Meat       False               Pepsi - Diet, 355 Ml
# 11         Meat        True                   Eggplant - Asian
# 12      Poultry       False             Nut - Chestnuts, Whole
# 13      Poultry        True             Liners - Banana, Paper
# 14      Produce       False          Juice - Cranberry, 341 Ml
# 15      Produce        True                           Bay Leaf
# 16      Seafood       False      Bread Crumbs - Japanese Style
# 17      Seafood        True                       Durian Fruit
# 18   Shell fish       False  Appetizer - Mini Egg Roll, Shrimp
# 19   Shell fish        True             Coffee Decaf Colombian
# 20       Snails       False   Pork - Back, Short Cut, Boneless
# 21       Snails        True                  Zucchini - Yellow
#
#     Max_Quantity_Sold
# 0               31981
# 1               31039
# 2               30988
# 3               31345
# 4               31053
# 5               31475
# 6               31425
# 7               31614
# 8               31542
# 9               31065
# 10              31373
# 11              31381
# 12              31490
# 13              31075
# 14              31299
# 15              31518
# 16              31767
# 17              30942
# 18              32179
# 19              32395
# 20              31146
# 21              31604

# %% [markdown]
# # Non-Allergic Products

# %%
#Filter only non-allergic products
allergic_false_products = allergic_max_values.loc[allergic_max_values['IsAllergic'] == False]

allergic_false_products
# Out:
#    CategoryName  IsAllergic                        ProductName  \
# 0     Beverages       False           Cheese - Taleggio D.o.p.
# 2       Cereals       False         Sole - Dover, Whole, Fresh
# 4   Confections       False                Initation Crab Meat
# 6         Dairy       False                     Apricots Fresh
# 8         Grain       False              Bandage - Fexible 1x3
# 10         Meat       False               Pepsi - Diet, 355 Ml
# 12      Poultry       False             Nut - Chestnuts, Whole
# 14      Produce       False          Juice - Cranberry, 341 Ml
# 16      Seafood       False      Bread Crumbs - Japanese Style
# 18   Shell fish       False  Appetizer - Mini Egg Roll, Shrimp
# 20       Snails       False   Pork - Back, Short Cut, Boneless
#
#     Max_Quantity_Sold
# 0               31981
# 2               30988
# 4               31053
# 6               31425
# 8               31542
# 10              31373
# 12              31490
# 14              31299
# 16              31767
# 18              32179
# 20              31146

# %%
#Maximum value in the "Max_Quantity_Sold" column
max_value_nonallergic = allergic_false_products["Max_Quantity_Sold"].max()
max_value_nonallergic
# Out:
# 32179

# %% [markdown]
# # Plot for Non-Allergic products

# %%
# Create a bar chart based upon the above data

max_quantity_false_list = allergic_false_products["Max_Quantity_Sold"].tolist()

colors = tuple(np.where(allergic_false_products["Max_Quantity_Sold"] == max_value_nonallergic , 'red', 'blue'))
allergic_false_products.plot(kind="bar",x = "ProductName",y = "Max_Quantity_Sold", color = colors, align="center")
    
# Set the limits of the y axis
plt.ylim(0, max(max_quantity_false_list)+10000)


# Give the chart a title, x label, and y label
plt.title("Most Sold Non-Allergic Product Per Category")
plt.xlabel("Product_Names")
plt.ylabel("Max_Quantity_Sold")

plt.savefig("output/Non_Allergic_Products")
plt.show()

# %% [markdown]
# # Allergic Products

# %%
#Filter only allergic products
allergic_true_products = allergic_max_values.loc[allergic_max_values['IsAllergic'] == True]
allergic_true_products
# Out:
#    CategoryName  IsAllergic                ProductName  Max_Quantity_Sold
# 1     Beverages        True             Mustard - Seed              31039
# 3       Cereals        True           Chocolate - Dark              31345
# 5   Confections        True  Tea - Herbal Sweet Dreams              31475
# 7         Dairy        True   Wine - White Cab Sauv.on              31614
# 9         Grain        True                Milk Powder              31065
# 11         Meat        True           Eggplant - Asian              31381
# 13      Poultry        True     Liners - Banana, Paper              31075
# 15      Produce        True                   Bay Leaf              31518
# 17      Seafood        True               Durian Fruit              30942
# 19   Shell fish        True     Coffee Decaf Colombian              32395
# 21       Snails        True          Zucchini - Yellow              31604

# %%
# #Maximum value in the "Max_Quantity_Sold" column
max_value_allergic = allergic_true_products["Max_Quantity_Sold"].max()
max_value_allergic

# max_quantity_list = allergic_true_products["Max_Quantity_Sold"].tolist
# Out:
# 32395

# %% [markdown]
# # Plot for Allergic products

# %%
# Create a bar chart based upon the above data

max_quantity_true_list = allergic_true_products["Max_Quantity_Sold"].tolist()

colors = tuple(np.where(allergic_true_products["Max_Quantity_Sold"] == max_value_allergic , 'red', 'blue'))
allergic_true_products.plot(kind="bar",x = "ProductName",y = "Max_Quantity_Sold", color = colors, align="center")
    
# Set the limits of the y axis
plt.ylim(0, max(max_quantity_true_list)+10000)

# Give the chart a title, x label, and y label
plt.title("Most Sold Allergic Product Per Category")
plt.xlabel("Product_Names")
plt.ylabel("Max_Quantity_Sold")

plt.savefig("output/Allergic_Products")
plt.show()
